# %%
from PIL import Image
 
im = Image.open(r"FloodNetV2/test/austin16-11-_png_jpg.rf.1c677db4c8a8d80f34e89c532636dd3c.jpg")
im.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>
